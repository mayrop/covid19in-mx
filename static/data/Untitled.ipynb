# %%
import re
import datetime
import csv

name = "covid-19-resultado-positivos-indre-2020-03-26"
lines = list()

# replacing excel dates
# see: https://stackoverflow.com/questions/14271791/converting-date-formats-python-unusual-date-formats-extract-ymd
def get_original_date(line):
    match = re.search(r'(\d{5})\s+', line)
    if not match:
        return "", ""
    
    m = match.group().replace(" ", "").replace(",","")
    delta = datetime.timedelta(int(m)-2)
    date = datetime.date(1900, 1, 1) + delta
    date = str(date.strftime("%d/%m/%Y"))
    
    return str(m), date   

with open('results/txt/' + name + '.txt', 'r') as reader:
    # Read and print the entire file line by line
    line = reader.readline()
    prefixes = list()
    while line != '':
        #print(line)
        if not re.match(r"^\d+", line.strip()):
            prefixes.append(re.sub(r"\s{2,}", ",", line.strip()))
            line = reader.readline()
            print(prefixes)
            continue
            
        #print(line)
                    
        # fixing date            
        orig_date, processed_date = get_original_date(line)
        line = line.replace(orig_date, processed_date)
        # so states / cities do not have spaces in between
        line = re.sub(r"([A-Za-z]) ([A-Za-z])", "\\1_\\2", line.strip())
        # some of the lines are \w+ / \w+
        line = re.sub(r"\s+([/,])\s+", "_\\1_", line.strip())
        line = re.sub(r"([/,])\s+", "\\1_", line.strip())
        # replacing dates
        line = re.sub("(\d+/\d+/\d+)", "\\1", line.strip())
        # first make sure to backup commas
        line = re.sub(",", ";", line.strip())
        # replace space with commas
        line = re.sub("\s+", ",", line.strip())
        
        # adding the original date
        line = line + "," + orig_date
        # replacing NAs
        line = re.sub(r",NA,", ",,", line.strip())
        # bring back spaces instead of underscore
        line = line.replace("_", " ")
        # splitting...
        line = list(line.split(","))
        
        # recovered cases...
        if '*' in line[1]:
            line[1] = line[1].replace("*", "")
            line.append("*")
        else:
            line.append("")

        # insert empty locality if needed
        if line[2] in ["M", "F"]:
            line.insert(2, "")
        
        lines.append(line)
        #print(line)
        
        prefixes = list()
        line = reader.readline()

with open('results/csv/' + name + '.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(lines)
# Out:
# Casos Confirmados a enfermedad por COVID-19.
#
# ['Casos Confirmados a enfermedad por COVID-19.']
#
#
# ['Casos Confirmados a enfermedad por COVID-19.', '']
#                                                          Identificación
#
# ['Casos Confirmados a enfermedad por COVID-19.', '', 'Identificación']
#                                             Fecha de                                    Fecha del
#
# ['Casos Confirmados a enfermedad por COVID-19.', '', 'Identificación', 'Fecha de,Fecha del']
#                                                           de COVID-19
#
# ['Casos Confirmados a enfermedad por COVID-19.', '', 'Identificación', 'Fecha de,Fecha del', 'de COVID-19']
#  N° Caso        Estado        Sexo   Edad   Inicio de                     Procedencia   llegada a
#
# ['Casos Confirmados a enfermedad por COVID-19.', '', 'Identificación', 'Fecha de,Fecha del', 'de COVID-19', 'N° Caso,Estado,Sexo,Edad,Inicio de,Procedencia,llegada a']
#                                                          por RT-PCR en
#
# ['Casos Confirmados a enfermedad por COVID-19.', '', 'Identificación', 'Fecha de,Fecha del', 'de COVID-19', 'N° Caso,Estado,Sexo,Edad,Inicio de,Procedencia,llegada a', 'por RT-PCR en']
#                                             síntomas                                      México
#
# ['Casos Confirmados a enfermedad por COVID-19.', '', 'Identificación', 'Fecha de,Fecha del', 'de COVID-19', 'N° Caso,Estado,Sexo,Edad,Inicio de,Procedencia,llegada a', 'por RT-PCR en', 'síntomas,México']
#                                                           tiempo real
#
# ['Casos Confirmados a enfermedad por COVID-19.', '', 'Identificación', 'Fecha de,Fecha del', 'de COVID-19', 'N° Caso,Estado,Sexo,Edad,Inicio de,Procedencia,llegada a', 'por RT-PCR en', 'síntomas,México', 'tiempo real']
#
#
# ['Casos Confirmados a enfermedad por COVID-19.', '', 'Identificación', 'Fecha de,Fecha del', 'de COVID-19', 'N° Caso,Estado,Sexo,Edad,Inicio de,Procedencia,llegada a', 'por RT-PCR en', 'síntomas,México', 'tiempo real', '']
#     1      CIUDAD DE MÉXICO    M      35    22/02/2020    confirmado         Italia     22/02/2020
#
#    2           SINALOA         M      41    22/02/2020    confirmado         Italia     21/02/2020
#
#    3       CIUDAD DE MÉXICO    M      59    23/02/2020    confirmado         Italia     22/02/2020
#
#    4          COAHUILA         F      20    27/02/2020    confirmado         Italia     25/02/2020
#
#    5           CHIAPAS         F      18    25/02/2020    confirmado         Italia     25/02/2020
#
#    6           MÉXICO          M      71    21/02/2020    confirmado         Italia     21/02/2020
#
#                                                                             Estados
#
# ['Estados']
#            CIUDAD DE MÉXICO
#
# ['Estados', 'CIUDAD DE MÉXICO']
#    7                           M      46    29/02/2020    confirmado        Unidos      29/02/2020
#
#    8         QUERETARO         M      43    09/03/2020    confirmado        España      06/03/2020
#
#                                                                             Estados
#
# ['Estados']
#            CIUDAD DE MÉXICO
#
# ['Estados', 'CIUDAD DE MÉXICO']
#    9                           M      41    07/03/2020    confirmado        Unidos      06/03/2020
#
#    10      CIUDAD DE MÉXICO    F      30    07/03/2020    confirmado        España      06/03/2020
#
#                                                                             Estados
#
# ['Estados']
#                MÉXICO
#
# ['Estados', 'MÉXICO']
#    11                          F      64    02/03/2020    confirmado        Unidos      29/02/2020
#
#    12        NUEVO LEÓN        M      57    04/03/2020    confirmado       Alemania     03/03/2020
#
#    13          MÉXICO          F      55    09/03/2020    confirmado        España      09/03/2020
#
#    14         DURANGO          M      58    06/03/2020    confirmado        España      28/02/2020
#
#    15        QUERETARO         F      65    10/03/2020    confirmado       Contacto        NA
#
#    16        QUERETARO         M      42    05/03/2020    confirmado         Italia     05/03/2020
#
#    17      CIUDAD DE MÉXICO    M      48    10/03/2020    confirmado        España      09/03/2020
#
#    18      CIUDAD DE MÉXICO    M      38    10/03/2020    confirmado        España      09/03/2020
#
#    19        QUERETARO         F      43    11/03/2020    confirmado       Contacto        NA
#
#    20          PUEBLA          M      31    05/03/2020    confirmado        España      09/03/2020
#
#    21      CIUDAD DE MÉXICO    M      37    11/03/2020    confirmado         Italia     11/03/2020
#
#    22          YUCATÁN         F      57    07/03/2020    confirmado        España      06/03/2020
#
#    23      CIUDAD DE MÉXICO    M      52    08/03/2020    confirmado        España      08/03/2020
#
#    24      CIUDAD DE MÉXICO    M      64    10/03/2020    confirmado       Contacto     10/03/2020
#
#    25      CIUDAD DE MÉXICO    M      68    04/03/2020    confirmado        España      10/03/2020
#
#    26       QUINTANA ROO       F      71    01/03/2020    confirmado         Italia     01/03/2020
#
#    27       SAN LUIS POTOSÍ    F      53    11/03/2020    confirmado        España      10/03/2020
#
#                                                                             Estados
#
# ['Estados']
#              NUEVO LEÓN
#
# ['Estados', 'NUEVO LEÓN']
#    28                          M      73    09/03/2020    confirmado        Unidos      10/03/2020
#
#    29        NUEVO LEÓN        M      30    09/03/2020    confirmado        España      07/03/2020
#
#    30          PUEBLA          M      31    09/03/2020    confirmado        España      08/03/2020
#
#    31      CIUDAD DE MÉXICO    F      33    10/03/2020    confirmado        Francia     08/03/2020
#
#    32          JALISCO         F      54    10/03/2020    confirmado        España      04/03/2020
#
#    33          JALISCO         F      64    01/03/2020    confirmado       Alemania     09/03/2020
#
#                                                                             Estados
#
# ['Estados']
#                MÉXICO
#
# ['Estados', 'MÉXICO']
#    34                          M      61    09/03/2020    confirmado        Unidos      03/03/2020
#
#    35      CIUDAD DE MÉXICO    M      45    07/03/2020    confirmado        España      09/03/2020
#
#                                                                             Estados
#
# ['Estados']
#            CIUDAD DE MÉXICO
#
# ['Estados', 'CIUDAD DE MÉXICO']
#    36                          F      62    11/03/2020    confirmado        Unidos      08/03/2020
#
#                                                                             Estados
#
# ['Estados']
#            CIUDAD DE MÉXICO
#
# ['Estados', 'CIUDAD DE MÉXICO']
#    37                          M      72    09/03/2020    confirmado        Unidos      07/03/2020
#
#    38      CIUDAD DE MÉXICO    M      41    10/03/2020    confirmado        España      08/03/2020
#
#    39          PUEBLA          M      30    09/03/2020    confirmado        España      09/03/2020
#
#    40      CIUDAD DE MÉXICO    M      38    11/03/2020    confirmado       Contacto        NA
#
#    41          OAXACA          F      30    09/03/2020    confirmado        España      09/03/2020
#
#                                                                             Estados
#
# ['Estados']
#                SINALOA
#
# ['Estados', 'SINALOA']
#    42                          M      25    09/03/2020    confirmado        Unidos      13/03/2020
#
# 43    SAN LUIS POTOSÍ   F   23   07/03/2020   confirmado   España     10/03/2020
#
# 44     QUERETARO        F   54   10/03/2020   confirmado   España     10/03/2020
#
#                                                            Estados
#
# ['Estados']
#          OAXACA
#
# ['Estados', 'OAXACA']
# 45                      M   61   10/03/2020   confirmado   Unidos     10/03/2020
#
# 46     QUERETARO        F   55   10/03/2020   confirmado   España     10/03/2020
#
# 47     NUEVO LEÓN       M   27   11/03/2020   confirmado   España     13/03/2020
#
#                                                            Estados
#
# ['Estados']
#        NUEVO LEÓN
#
# ['Estados', 'NUEVO LEÓN']
# 48                      M   46   06/03/2020   confirmado   Unidos     03/03/2020
#
# 49      GUERRERO        M   32   12/03/2020   confirmado   Contacto      NA
#
# 50      DURANGO         M   32   11/03/2020   confirmado   Alemania   11/03/2020
#
# 51      GUERRERO        F   22   09/03/2020   confirmado   España     12/03/2020
#
# 52       PUEBLA         F   27   05/03/2020   confirmado   España     09/03/2020
#
#                                                            Estados
#
# ['Estados']
#      CIUDAD DE MÉXICO
#
# ['Estados', 'CIUDAD DE MÉXICO']
# 53                      F   70   07/03/2020   confirmado   Unidos     08/03/2020
#
# 54   CIUDAD DE MÉXICO   M   32   10/03/2020   confirmado   Contacto      NA
#
# 55   CIUDAD DE MÉXICO   M   59   07/03/2020   confirmado   España     04/03/2020
#
#                                                            Estados
#
# ['Estados']
#      CIUDAD DE MÉXICO
#
# ['Estados', 'CIUDAD DE MÉXICO']
# 56                      M   70   09/03/2020   confirmado   Unidos     08/03/2020
#
# 57      DURANGO         F   38   09/03/2020   confirmado   España     12/03/2020
#
# 58   AGUASCALIENTES     M   25   14/03/2020   confirmado   España     12/03/2020
#
# 59       PUEBLA         F   31   10/03/2020   confirmado   Contacto      NA
#
# 60     QUERETARO        F   45   13/03/2020   confirmado   España     10/03/2020
#
# 61       MÉXICO         M   27   13/03/2020   confirmado   Contacto      NA
#
#                                                            Estados
#
# ['Estados']
#          MÉXICO
#
# ['Estados', 'MÉXICO']
# 62                      F   47   05/03/2020   confirmado    Unidos    29/02/2020
#
# 63       MÉXICO         F   59   07/03/2020   confirmado   Francia    08/03/2020
#
# 64   CIUDAD DE MÉXICO   M   41   09/03/2020   confirmado   Contacto      NA
#
# 65     GUANAJUATO       M   39   12/03/2020   confirmado   Alemania   10/03/2020
#
#                                                             Estados
#
# ['Estados']
#        NUEVO LEÓN
#
# ['Estados', 'NUEVO LEÓN']
# 66                      M   72   11/03/2020   confirmado    Unidos    10/03/2020
#
# 67      CHIHUAHUA       M   29   12/03/2020   confirmado   Alemania   12/03/2020
#
# 68    QUINTANA ROO      F   50   08/03/2020   confirmado   España     11/03/2020
#
# 69    QUINTANA ROO      F   19   13/03/2020   confirmado   España     11/03/2020
#
# 70    QUINTANA ROO      M   44   11/03/2020   confirmado   Contacto      NA
#
# 71       MÉXICO         F   49   13/03/2020   confirmado   España     13/03/2020
#
#                                                            Estados
#
# ['Estados']
#          PUEBLA
#
# ['Estados', 'PUEBLA']
# 72                      M   32   11/03/2020   confirmado   Unidos     07/03/2020
#
# 73     NUEVO LEÓN       F   74   09/03/2020   confirmado   España     12/03/2020
#
# 74     NUEVO LEÓN       F   80   09/03/2020   confirmado   España     12/03/2020
#
#                                                            Estados
#
# ['Estados']
#        NUEVO LEÓN
#
# ['Estados', 'NUEVO LEÓN']
# 75                      M   71   07/03/2020   confirmado   Unidos     10/03/2020
#
# 76     NUEVO LEÓN       M   53   09/03/2020   confirmado   España     10/03/2020
#
#                                                            Estados
#
# ['Estados']
#        NUEVO LEÓN
#
# ['Estados', 'NUEVO LEÓN']
# 77                      M   42   02/03/2020   confirmado   Unidos     02/03/2020
#
#                                                            Estados
#
# ['Estados']
#          MÉXICO
#
# ['Estados', 'MÉXICO']
# 78                      M   45   11/03/2020   confirmado   Unidos     01/03/2020
#
#                                                            Estados
#
# ['Estados']
#        NUEVO LEÓN
#
# ['Estados', 'NUEVO LEÓN']
# 79                      M   33   09/03/2020   confirmado   Unidos     12/03/2020
#
#                                                            Estados
#
# ['Estados']
#        NUEVO LEÓN
#
# ['Estados', 'NUEVO LEÓN']
# 80                      F   27   12/03/2020   confirmado   Unidos     12/03/2020
#
# 81       YUCATÁN        F   31   08/03/2020   confirmado   Francia    10/03/2020
#
# 82       YUCATÁN        M   21   13/03/2020   confirmado   España     13/03/2020
#
# 83     TAMAULIPAS       M   55   13/03/2020   confirmado   Singapur   11/03/2020
#
# 84       PUEBLA         F   27   09/03/2020   confirmado   España     09/03/2020
#
# 85       PUEBLA         M   31   09/03/2020   confirmado   España     09/03/2020
#
# 86       YUCATÁN        F   54   11/03/2020   confirmado   España     08/03/2020
#
#                                                            Estados
#
# ['Estados']
#          SONORA
#
# ['Estados', 'SONORA']
# 87                      M   72   11/03/2020   confirmado   Unidos     11/03/2020
#
# 88       JALISCO        M   49   06/03/2020   confirmado   España     04/03/2020
#
#                                                            Estados
#
# ['Estados']
#          JALISCO
#
# ['Estados', 'JALISCO']
# 89                      M   41   10/03/2020   confirmado   Unidos     29/02/2020
#
# 90        JALISCO        F   56   11/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
#           YUCATÁN
#
# ['Estados', 'YUCATÁN']
# 91                       M   37   09/03/2020   confirmado    Unidos    06/03/2020
#
# 92      NUEVO LEÓN       M   19   07/03/2020   confirmado   Contacto   10/03/2020
#
#                                                             Estados
#
# ['Estados']
#         NUEVO LEÓN
#
# ['Estados', 'NUEVO LEÓN']
# 93                       M   34   12/03/2020   confirmado    Unidos    07/03/2020
#
#                                                             Estados
#
# ['Estados']
#         NUEVO LEÓN
#
# ['Estados', 'NUEVO LEÓN']
# 94                       M   41   10/03/2020   confirmado    Unidos    07/03/2020
#
#                                                             Estados
#
# ['Estados']
#         NUEVO LEÓN
#
# ['Estados', 'NUEVO LEÓN']
# 95                       M   46   11/03/2020   confirmado    Unidos    09/03/2020
#
# 96      NUEVO LEÓN       M   21   14/03/2020   confirmado   España     15/03/2020
#
# 97      NUEVO LEÓN       M   21   15/03/2020   confirmado   España     13/03/2020
#
# 98        YUCATÁN        F   21   13/03/2020   confirmado   España     13/03/2020
#
# 99        YUCATÁN        M   25   11/03/2020   confirmado   España     15/03/2020
#
# 100       JALISCO        F   36   10/03/2020   confirmado   Contacto      NA
#
# 101   CIUDAD DE MÉXICO   M   53   09/03/2020   confirmado   España     09/03/2020
#
# 102   CIUDAD DE MÉXICO   F   53   06/03/2020   confirmado   España     09/03/2020
#
#                                                             Estados
#
# ['Estados']
#           MÉXICO
#
# ['Estados', 'MÉXICO']
# 103                      M   56   07/03/2020   confirmado   Unidos     05/03/2020
#
# 104      VERACRUZ        F   21   03/03/2020   confirmado   España     12/03/2020
#
# 105      VERACRUZ        M   24   14/03/2020   confirmado   España     14/03/2020
#
# 106    SAN LUIS POTOSÍ   M   32   14/03/2020   confirmado   España     14/03/2020
#
# 107       PUEBLA         M   25   10/03/2020   confirmado   España     09/03/2020
#
# 108       YUCATÁN        F   26   08/03/2020   confirmado   España     14/03/2020
#
# 109       COLIMA         M   46   15/03/2020   confirmado   Alemania   13/03/2020
#
#                                                              Estados
#
# ['Estados']
#       BAJA CALIFORNIA
#
# ['Estados', 'BAJA CALIFORNIA']
# 110                      F   54   11/03/2020   confirmado    Unidos    02/03/2020
#
# 111   BAJA CALIFORNIA    F   57   13/03/2020   confirmado   Contacto   16/03/2020
#
#                                                             Estados
#
# ['Estados']
#       CIUDAD DE MÉXICO
#
# ['Estados', 'CIUDAD DE MÉXICO']
# 112                      M   47   12/03/2020   confirmado    Unidos    12/03/2020
#
#                                                             Estados
#
# ['Estados']
#       CIUDAD DE MÉXICO
#
# ['Estados', 'CIUDAD DE MÉXICO']
# 113                      M   43   14/03/2020   confirmado    Unidos    12/03/2020
#
# 114       HIDALGO        M   39   07/03/2020   confirmado   Francia    06/03/2020
#
# 115       SONORA         M   44   12/03/2020   confirmado    Italia    10/03/2020
#
# 116       TABASCO        F   61   14/03/2020   confirmado   Francia    16/03/2020
#
#                                                             Estados
#
# ['Estados']
#           PUEBLA
#
# ['Estados', 'PUEBLA']
# 117                      M   64   08/03/2020   confirmado   Unidos     08/03/2020
#
#                                                             Estados
#
# ['Estados']
#           SINALOA
#
# ['Estados', 'SINALOA']
# 118                      F   25   15/03/2020   confirmado   Unidos     17/03/2020
#
#                                                             Estados
#
# ['Estados']
#           HIDALGO
#
# ['Estados', 'HIDALGO']
# 119                      M   43   08/03/2020   confirmado   Unidos     10/02/2020
#
# 120    SAN LUIS POTOSÍ   M   39   16/03/2020   confirmado   España     14/03/2020
#
# 121    SAN LUIS POTOSÍ   M   31   15/03/2020   confirmado   Francia    14/03/2020
#
# 122    SAN LUIS POTOSÍ   M   44   16/03/2020   confirmado   España     16/03/2020
#
# 123    SAN LUIS POTOSÍ   F   63   15/03/2020   confirmado   España     17/03/2020
#
# 124   CIUDAD DE MÉXICO   M   28   16/03/2020   confirmado   Contacto      NA
#
# 125       PUEBLA         F   24   16/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
#           CHIAPAS
#
# ['Estados', 'CHIAPAS']
# 126                      M   63   23/03/2020   confirmado    Unidos    11/03/2020
#
#                                                             Estados
#
# ['Estados']
#       CIUDAD DE MÉXICO
#
# ['Estados', 'CIUDAD DE MÉXICO']
# 127                      M   35   10/03/2020   confirmado    Unidos    10/03/2020
#
#                                                             Estados
#
# ['Estados']
#         GUANAJUATO
#
# ['Estados', 'GUANAJUATO']
# 128                      F   18   10/03/2020   confirmado    Unidos    13/03/2020
#
# 129     TAMAULIPAS       F   23   16/03/2020   confirmado   España     12/03/2020
#
#                                                             Estados
#
# ['Estados']
#        QUINTANA ROO
#
# ['Estados', 'QUINTANA ROO']
# 130                      M   17   09/03/2020   confirmado   Unidos     09/03/2020
#
# 131    QUINTANA ROO      M   39   16/03/2020   confirmado    Italia    01/03/2020
#
# 132      GUERRERO        M   79   15/03/2020   confirmado   España     13/03/2020
#
# 133     GUANAJUATO       F   27   14/03/2020   confirmado   España     14/03/2020
#
# 134     GUANAJUATO       F   52   12/03/2020   confirmado   España     14/03/2020
#
# 135    QUINTANA ROO      M   42   14/03/2020   confirmado   España     13/03/2020
#
# 136     QUERETARO        M   25   08/03/2020   confirmado   España     16/03/2020
#
# 137       MÉXICO         F   52   10/03/2020   confirmado   España     12/03/2020
#
# 138       YUCATÁN        F   27   13/03/2020   confirmado   Contacto      NA
#
# 139       YUCATÁN        M   51   14/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
#       BAJA CALIFORNIA
#
# ['Estados', 'BAJA CALIFORNIA']
# 140                      M   72   09/03/2020   confirmado    Unidos    10/03/2020
#
#                                                             Estados
#
# ['Estados']
#           YUCATÁN
#
# ['Estados', 'YUCATÁN']
# 141                      M   32   11/03/2020   confirmado    Unidos       NA
#
# 142       YUCATÁN        M   30   16/03/2020   confirmado   España     11/03/2020
#
#                                                             Estados
#
# ['Estados']
#           YUCATÁN
#
# ['Estados', 'YUCATÁN']
# 143                      M   45   13/03/2020   confirmado   Unidos     13/03/2020
#
#                                                             Estados
#
# ['Estados']
#        QUINTANA ROO
#
# ['Estados', 'QUINTANA ROO']
# 144                      M   45   15/03/2020   confirmado   Unidos     15/03/2020
#
# 145       JALISCO        M   54   13/03/2020   confirmado   Contacto      NA
#
# 146       JALISCO        M   27   13/03/2020   confirmado   España     15/03/2020
#
# 147    QUINTANA ROO      F   22   16/03/2020   confirmado   España     16/03/2020
#
# 148       JALISCO        F   49   12/03/2020   confirmado   España     09/03/2020
#
# 149       JALISCO        M   19   16/03/2020   confirmado   España     13/03/2020
#
#                                                             Estados
#
# ['Estados']
#          GUERRERO
#
# ['Estados', 'GUERRERO']
# 150                      F   38   13/03/2020   confirmado   Unidos     01/03/2020
#
#                                                             Estados
#
# ['Estados']
#       CIUDAD DE MÉXICO
#
# ['Estados', 'CIUDAD DE MÉXICO']
# 151                      M   46   12/03/2020   confirmado   Unidos     10/03/2020
#
#                                                             Estados
#
# ['Estados']
#       CIUDAD DE MÉXICO
#
# ['Estados', 'CIUDAD DE MÉXICO']
# 152                      M   35   11/03/2020   confirmado   Unidos     05/03/2020
#
#                                                             Estados
#
# ['Estados']
#       AGUASCALIENTES
#
# ['Estados', 'AGUASCALIENTES']
# 153                      M   70   15/03/2020   confirmado   Unidos     13/03/2020
#
# 154   CIUDAD DE MÉXICO   M   59   13/03/2020   confirmado   Contacto      NA
#
# 155   AGUASCALIENTES     M   50   16/03/2020   confirmado   España     17/03/2020
#
# 156      VERACRUZ        F   64   18/03/2020   confirmado   España     15/03/2020
#
#                                                             Estados
#
# ['Estados']
#         NUEVO LEÓN
#
# ['Estados', 'NUEVO LEÓN']
# 157                      M   35   09/03/2020   confirmado   Unidos     09/03/2020
#
# 158     NUEVO LEÓN       M   42   16/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
#          DURANGO
#
# ['Estados', 'DURANGO']
# 159                      M   74   15/03/2020   confirmado    Unidos    03/03/2020
#
#                                                             Estados
#
# ['Estados']
#          MORELOS
#
# ['Estados', 'MORELOS']
# 160                      M   37   14/03/2020   confirmado    Unidos    07/03/2020
#
# 161     QUERETARO        M   34   15/03/2020   confirmado   Francia    15/03/2020
#
# 162      VERACRUZ        F   63   14/03/2020   confirmado   España     13/03/2020
#
# 163     NUEVO LEÓN       F   29   13/03/2020   confirmado   España     14/03/2020
#
#                                                             Estados
#
# ['Estados']
#          MORELOS
#
# ['Estados', 'MORELOS']
# 164                      F   54   17/03/2020   confirmado   Unidos     17/03/2020
#
# 165       JALISCO        F   73   14/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 166                      M   52   14/03/2020   confirmado    Unidos    14/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 167                      M   50   04/03/2020   confirmado    Unidos    07/03/2020
#
# 168    QUINTANA ROO      M   35   15/03/2020   confirmado   Alemania   14/03/2020
#
#                                                              Estados
#
# ['Estados']
#        QUINTANA ROO
#
# ['Estados', 'QUINTANA ROO']
# 169                      F   30   14/03/2020   confirmado    Unidos    14/03/2020
#
#                                                              Estados
#
# ['Estados']
#         NUEVO LEÓN
#
# ['Estados', 'NUEVO LEÓN']
# 170                      M   28   14/03/2020   confirmado    Unidos    12/03/2020
#
# 171   AGUASCALIENTES     M   42   10/03/2020   confirmado   España     11/03/2020
#
# 172     NUEVO LEÓN       F   48   11/03/2020   confirmado   España     13/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 173                      F   19   11/03/2020   confirmado   Unidos     07/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 174                      F   29   14/03/2020   confirmado   Unidos     07/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 175                      M   41   08/03/2020   confirmado   Unidos     09/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 176                      M   54   07/03/2020   confirmado   Unidos     07/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 177                      F   62   09/03/2020   confirmado   Unidos     23/02/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 178                      M   42   12/03/2020   confirmado   Unidos     11/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 179                      M   49   13/03/2020   confirmado   Unidos     08/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 180                      M   29   08/03/2020   confirmado   Unidos     07/03/2020
#
# 181       JALISCO        M   19   14/03/2020   confirmado   España     13/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 182                      M   63   14/03/2020   confirmado   Unidos     14/03/2020
#
# 183       JALISCO        F   35   11/03/2020   confirmado    Italia    14/03/2020
#
# 184       JALISCO        M   44   11/03/2020   confirmado    Italia    11/03/2020
#
# 185       PUEBLA         F   32   15/03/2020   confirmado   España     15/03/2020
#
# 186       CHIAPAS        M   47   14/03/2020   confirmado   Alemania   13/03/2020
#
#                                                              Estados
#
# ['Estados']
#         QUERETARO
#
# ['Estados', 'QUERETARO']
# 187                      M   51   16/03/2020   confirmado    Unidos    15/03/2020
#
# 188       MÉXICO         F   33   15/03/2020   confirmado   España     05/03/2020
#
# 189       MÉXICO         M   31   03/03/2020   confirmado   España     01/03/2020
#
# 190   BAJA CALIFORNIA    M   62   17/03/2020   confirmado   Contacto      NA
#
# 191     QUERETARO        M   34   18/03/2020   confirmado   Francia    16/03/2020
#
# 192   CIUDAD DE MÉXICO   F   38   14/03/2020   confirmado   Contacto      NA
#
# 193       MÉXICO         M   55   11/03/2020   confirmado   Contacto      NA
#
# 194     NUEVO LEÓN       M   53   17/03/2020   confirmado   Contacto      NA
#
# 195     NUEVO LEÓN       M   58   15/03/2020   confirmado   España     14/03/2020
#
# 196     NUEVO LEÓN       M   61   15/03/2020   confirmado   España     14/03/2020
#
# 197     NUEVO LEÓN       F   59   17/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
#           TABASCO
#
# ['Estados', 'TABASCO']
# 198                      M   46   09/03/2020   confirmado    Unidos    11/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 199                      F   75   08/03/2020   confirmado    Unidos    14/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 200                      M   80   14/03/2020   confirmado    Unidos    14/03/2020
#
# 201     NUEVO LEÓN       F   31   10/03/2020   confirmado   Contacto   10/03/2020
#
#                                                             Estados
#
# ['Estados']
#       CIUDAD DE MÉXICO
#
# ['Estados', 'CIUDAD DE MÉXICO']
# 202                      M   38   10/03/2020   confirmado    Unidos    07/03/2020
#
# 203   CIUDAD DE MÉXICO   F   35   09/03/2020   confirmado   Contacto      NA
#
# 204   CIUDAD DE MÉXICO   M   61   16/03/2020   confirmado   España     11/03/2020
#
# 205   CIUDAD DE MÉXICO   F   37   14/03/2020   confirmado   Contacto      NA
#
# 206   CIUDAD DE MÉXICO   M   43   13/03/2020   confirmado   Contacto      NA
#
# 207   BAJA CALIFORNIA    M   26   15/03/2020   confirmado   Francia    13/03/2020
#
# 208       HIDALGO        F   57   14/03/2020   confirmado   España     16/03/2020
#
# 209       PUEBLA         M   21   17/03/2020   confirmado   España     15/03/2020
#
#                                                             Estados
#
# ['Estados']
#       BAJA CALIFORNIA
#
# ['Estados', 'BAJA CALIFORNIA']
# 210                      F   34   11/03/2020   confirmado   Unidos     08/03/2020
#
# 211   CIUDAD DE MÉXICO   M   0    16/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
#           PUEBLA
#
# ['Estados', 'PUEBLA']
# 212                      M   56   14/03/2020   confirmado    Unidos    07/03/2020
#
# 213       NAYARIT        F   48   17/03/2020   confirmado   España     17/03/2020
#
#                                                             Estados
#
# ['Estados']
#           PUEBLA
#
# ['Estados', 'PUEBLA']
# 214                      M   24   14/03/2020   confirmado   Unidos     07/03/2020
#
#                                                             Estados
#
# ['Estados']
#         CHIHUAHUA
#
# ['Estados', 'CHIHUAHUA']
# 215                      F   18   15/03/2020   confirmado   Unidos     14/03/2020
#
# 216   BAJA CALIFORNIA    M   39   17/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
#         QUERETARO
#
# ['Estados', 'QUERETARO']
# 217                      F   29   10/03/2020   confirmado    Unidos    01/03/2020
#
# 218       JALISCO        M   77   13/03/2020   confirmado   Contacto      NA
#
# 219       TABASCO        M   33   14/03/2020   confirmado   España     18/03/2020
#
# 220   AGUASCALIENTES     M   44   17/03/2020   confirmado   España     17/03/2020
#
# 221       JALISCO        M   20   17/03/2020   confirmado   Contacto      NA
#
# 222      ZACATECAS       M   38   08/03/2020   confirmado   Contacto      NA
#
# 223     QUERETARO        M   29   18/03/2020   confirmado   España     16/03/2020
#
# 224   CIUDAD DE MÉXICO   M   33   11/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
#         NUEVO LEÓN
#
# ['Estados', 'NUEVO LEÓN']
# 225                      M   32   15/03/2020   confirmado    Unidos    16/03/2020
#
#                                                             Estados
#
# ['Estados']
#         NUEVO LEÓN
#
# ['Estados', 'NUEVO LEÓN']
# 226                      F   27   18/03/2020   confirmado   Unidos     14/03/2020
#
#                                                             Estados
#
# ['Estados']
#         NUEVO LEÓN
#
# ['Estados', 'NUEVO LEÓN']
# 227                      M   35   17/03/2020   confirmado   Unidos     15/03/2020
#
#                                                             Estados
#
# ['Estados']
#           PUEBLA
#
# ['Estados', 'PUEBLA']
# 228                      F   30   16/03/2020   confirmado   Unidos     15/03/2020
#
# 229   CIUDAD DE MÉXICO   M   27   15/03/2020   confirmado   Francia    15/03/2020
#
# 230   CIUDAD DE MÉXICO   M   71   04/03/2020   confirmado   España     14/03/2020
#
# 231   CIUDAD DE MÉXICO   F   25   09/03/2020   confirmado   España     13/03/2020
#
# 232   CIUDAD DE MÉXICO   M   43   08/03/2020   confirmado   España     04/03/2020
#
# 233   CIUDAD DE MÉXICO   F   31   03/03/2020   confirmado   Alemania   09/03/2020
#
# 234      VERACRUZ        M   31   16/03/2020   confirmado   España     13/03/2020
#
# 235     QUERETARO        M   29   16/03/2020   confirmado   Contacto      NA
#
# 236      DURANGO         F   68   18/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
#       BAJA CALIFORNIA
#
# ['Estados', 'BAJA CALIFORNIA']
# 237                      F   26   13/03/2020   confirmado    Unidos    16/03/2020
#
# 238    SAN LUIS POTOSÍ   F   20   09/03/2020   confirmado   España     17/03/2020
#
# 239   CIUDAD DE MÉXICO   F   54   15/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 240                      M   58   17/03/2020   confirmado    Unidos    04/03/2020
#
#                                                             Estados
#
# ['Estados']
#       BAJA CALIFORNIA
#
# ['Estados', 'BAJA CALIFORNIA']
# 241                      M   35   18/03/2020   confirmado    Unidos    16/03/2020
#
#                                                             Estados
#
# ['Estados']
#          VERACRUZ
#
# ['Estados', 'VERACRUZ']
# 242                      F   35   14/03/2020   confirmado    Unidos    13/03/2020
#
# 243       JALISCO        M   53   17/03/2020   confirmado   Contacto      NA
#
# 244      VERACRUZ        M   27   17/03/2020   confirmado   Contacto   16/03/2020
#
# 245    QUINTANA ROO      M   51   11/03/2020   confirmado   España     16/03/2020
#
# 246     TAMAULIPAS       F   33   16/03/2020   confirmado   Francia    07/03/2020
#
#                                                             Estados
#
# ['Estados']
#        SAN LUIS POTOSÍ
#
# ['Estados', 'SAN LUIS POTOSÍ']
# 247                      M   46   12/03/2020   confirmado   Unidos     12/03/2020
#
# 248   CIUDAD DE MÉXICO   M   42   06/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
#       CIUDAD DE MÉXICO
#
# ['Estados', 'CIUDAD DE MÉXICO']
# 249                      F   35   16/03/2020   confirmado    Unidos    09/03/2020
#
# 250       JALISCO        M   29   17/03/2020   confirmado   Singapur   09/03/2020
#
#                                                              Estados
#
# ['Estados']
#           TABASCO
#
# ['Estados', 'TABASCO']
# 251                      F   37   10/03/2020   confirmado    Unidos    11/03/2020
#
# 252   CIUDAD DE MÉXICO   M   47   14/03/2020   confirmado   España     16/03/2020
#
# 253   CIUDAD DE MÉXICO   M   34   14/03/2020   confirmado   Francia    12/03/2020
#
# 254       JALISCO        M   55   09/03/2020   confirmado   España     12/03/2020
#
# 255   CIUDAD DE MÉXICO   F   40   18/03/2020   confirmado   Contacto      NA
#
# 256       JALISCO        M   58   17/03/2020   confirmado   Contacto      NA
#
#       BAJA CALIFORNIA                                       Estados
#
# ['BAJA CALIFORNIA,Estados']
# 257         SUR          M   48   16/03/2020   confirmado    Unidos    14/03/2020
#
# 258      COAHUILA        F   41   18/03/2020   confirmado   España     14/03/2020
#
#                                                             Estados
#
# ['Estados']
#          CHIHUAHUA
#
# ['Estados', 'CHIHUAHUA']
# 259                      M   47   18/03/2020   confirmado   Unidos     13/03/2020
#
# 260   CIUDAD DE MÉXICO   F   48   13/03/2020   confirmado   Contacto      NA
#
# 261   CIUDAD DE MÉXICO   M   35   08/03/2020   confirmado   España     08/03/2020
#
#                                                             Estados
#
# ['Estados']
#          COAHUILA
#
# ['Estados', 'COAHUILA']
# 262                      M   29   17/03/2020   confirmado   Unidos     15/03/2020
#
# 263   CIUDAD DE MÉXICO   M   52   11/03/2020   confirmado   Contacto      NA
#
# 264   CIUDAD DE MÉXICO   M   25   13/03/2020   confirmado   Contacto      NA
#
# 265     MICHOACÁN        M   36   09/03/2020   confirmado   España     15/03/2020
#
# 266       SINALOA        M   55   17/03/2020   confirmado   Contacto      NA
#
# 267   BAJA CALIFORNIA    M   27   13/03/2020   confirmado   Francia    13/03/2020
#
# 268      CHIHUAHUA       F   19   13/03/2020   confirmado   España     14/03/2020
#
# 269   CIUDAD DE MÉXICO   M   37   16/03/2020   confirmado   España     16/03/2020
#
# 270      CHIHUAHUA       F   21   16/03/2020   confirmado   España     14/03/2020
#
# 271   CIUDAD DE MÉXICO   M   51   17/03/2020   confirmado   Contacto   08/03/2020
#
# 272       YUCATÁN        F   40   15/03/2020   confirmado   Contacto      NA
#
# 273   CIUDAD DE MÉXICO   M   36   14/03/2020   confirmado   Contacto      NA
#
# 274       HIDALGO        F   55   12/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
#        SAN LUIS POTOSÍ
#
# ['Estados', 'SAN LUIS POTOSÍ']
# 275                      F   27   17/03/2020   confirmado    Unidos    18/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 276                      F   38   15/03/2020   confirmado    Unidos    16/03/2020
#
# 277    SAN LUIS POTOSÍ   M   21   19/03/2020   confirmado   Contacto   18/03/2020
#
# 278    SAN LUIS POTOSÍ   M   34   18/03/2020   confirmado   Francia    05/03/2020
#
# 279      CAMPECHE        M   52   12/03/2020   confirmado   España     18/03/2020
#
# 280       HIDALGO        F   26   18/03/2020   confirmado   Francia    17/03/2020
#
# 281       TABASCO        F   71   17/03/2020   confirmado   España     17/03/2020
#
#                                                             Estados
#
# ['Estados']
#           YUCATÁN
#
# ['Estados', 'YUCATÁN']
# 282                      F   17   10/03/2020   confirmado   Unidos     08/03/2020
#
#                                                             Estados
#
# ['Estados']
#           YUCATÁN
#
# ['Estados', 'YUCATÁN']
# 283                      F   19   10/03/2020   confirmado   Unidos     08/03/2020
#
#                                                             Estados
#
# ['Estados']
#           YUCATÁN
#
# ['Estados', 'YUCATÁN']
# 284                      M   39   14/03/2020   confirmado   Unidos     14/03/2020
#
# 285       SONORA         M   30   18/03/2020   confirmado   Francia    13/03/2020
#
# 286     MICHOACÁN        F   57   15/03/2020   confirmado   Contacto   15/03/2020
#
# 287     MICHOACÁN        M   57   18/03/2020   confirmado   Contacto   15/03/2020
#
# 288       YUCATÁN        M   31   17/03/2020   confirmado   Contacto      NA
#
# 289   BAJA CALIFORNIA    F   49   12/03/2020   confirmado   Contacto      NA
#
# 290      ZACATECAS       M   39   19/03/2020   confirmado   Contacto   19/03/2020
#
#                                                             Estados
#
# ['Estados']
#           COLIMA
#
# ['Estados', 'COLIMA']
# 291                      F   34   12/03/2020   confirmado    Unidos    11/03/2020
#
# 292       MÉXICO         M   44   19/02/2020   confirmado    Italia    22/02/2020
#
# 293       MÉXICO         F   52   10/03/2020   confirmado   España     12/03/2020
#
#                                                             Estados
#
# ['Estados']
#          COAHUILA
#
# ['Estados', 'COAHUILA']
# 294                      M   43   16/03/2020   confirmado   Unidos     13/03/2020
#
#                                                             Estados
#
# ['Estados']
#           MÉXICO
#
# ['Estados', 'MÉXICO']
# 295                      M   31   13/03/2020   confirmado   Unidos     07/03/2020
#
#                                                             Estados
#
# ['Estados']
#         GUANAJUATO
#
# ['Estados', 'GUANAJUATO']
# 296                      M   34   16/03/2020   confirmado   Unidos     17/03/2020
#
# 297     GUANAJUATO       F   58   16/03/2020   confirmado   Francia    17/03/2020
#
#                                                             Estados
#
# ['Estados']
#         GUANAJUATO
#
# ['Estados', 'GUANAJUATO']
# 298                      M   43   18/03/2020   confirmado   Unidos     18/03/2020
#
# 299     TAMAULIPAS       F   21   16/03/2020   confirmado   España     12/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 300                      M   25   13/03/2020   confirmado   Unidos     06/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 301                      M   40   10/03/2020   confirmado   Unidos     07/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 302                      F   38   11/03/2020   confirmado   Unidos     07/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 303                      M   32   13/03/2020   confirmado   Unidos     02/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 304                      M   30   18/03/2020   confirmado   Unidos     09/03/2020
#
#                                                             Estados
#
# ['Estados']
#          COAHUILA
#
# ['Estados', 'COAHUILA']
# 305                      M   42   18/03/2020   confirmado   Unidos     11/03/2020
#
#                                                             Estados
#
# ['Estados']
#          COAHUILA
#
# ['Estados', 'COAHUILA']
# 306                      M   11   18/03/2020   confirmado   Unidos     11/03/2020
#
#                                                             Estados
#
# ['Estados']
#          COAHUILA
#
# ['Estados', 'COAHUILA']
# 307                      M   53   17/03/2020   confirmado   Unidos     11/03/2020
#
#                                                             Estados
#
# ['Estados']
#          COAHUILA
#
# ['Estados', 'COAHUILA']
# 308                      M   42   18/03/2020   confirmado   Unidos        NA
#
# 309       MÉXICO         M   46   18/03/2020   confirmado   Contacto      NA
#
# 310       MÉXICO         M   62   16/03/2020   confirmado   España     19/03/2020
#
#                                                             Estados
#
# ['Estados']
#           JALISCO
#
# ['Estados', 'JALISCO']
# 311                      M   24   17/03/2020   confirmado   Unidos     15/03/2020
#
# 312       YUCATÁN        F   42   18/03/2020   confirmado   Francia    18/03/2020
#
#                                                             Estados
#
# ['Estados']
#          COAHUILA
#
# ['Estados', 'COAHUILA']
# 313                      F   30   13/03/2020   confirmado   Unidos     18/03/2020
#
# 314       HIDALGO        F   40   19/03/2020   confirmado   Contacto   13/03/2020
#
# 315     NUEVO LEÓN       M   60   14/03/2020   confirmado   España     13/03/2020
#
# 316       OAXACA         M   22   16/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
# 317     NUEVO LEÓN       M   57   13/03/2020   confirmado    Unidos    12/03/2020
#
#                                                             Estados
#
# ['Estados']
# 318     NUEVO LEÓN       M   22   14/03/2020   confirmado    Unidos    13/03/2020
#
# 319      COAHUILA        M   76   20/03/2020   confirmado   España     14/03/2020
#
# 320      COAHUILA        M   42   20/03/2020   confirmado   España     14/03/2020
#
# 321      COAHUILA        F   42   20/03/2020   confirmado   España     14/03/2020
#
# 322       HIDALGO        F   19   20/03/2020   confirmado   Contacto      NA
#
# 323       SONORA         M   22   11/03/2020   confirmado   España     17/03/2020
#
#       BAJA CALIFORNIA
#
# ['BAJA CALIFORNIA']
# 324         SUR          F   33   16/03/2020   confirmado   Contacto   07/03/2020
#
# 325     QUERETARO        M   37   16/03/2020   confirmado   Contacto      NA
#
# 326       JALISCO        M   55   13/03/2020   confirmado   Contacto      NA
#
# 327       MÉXICO         M   24   20/03/2020   confirmado    Italia    14/03/2020
#
# 328       MÉXICO         F   29   20/03/2020   confirmado   España     15/03/2020
#
#                                                             Estados
#
# ['Estados']
# 329       MÉXICO         F   29   12/03/2020   confirmado   Unidos     27/02/2020
#
# 330     QUERETARO        F   30   21/03/2020   confirmado   España     15/03/2020
#
# 331      CAMPECHE        F   59   06/03/2020   confirmado   España     15/03/2020
#
# 332    QUINTANA ROO      M   65   18/03/2020   confirmado   España     15/03/2020
#
# 333       PUEBLA         M   29   13/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
# 334       PUEBLA         M   33   13/03/2020   confirmado    Unidos    12/03/2020
#
#                                                             Estados
#
# ['Estados']
# 335       JALISCO        M   28   16/03/2020   confirmado    Unidos    06/03/2020
#
# 336       PUEBLA         F   49   14/03/2020   confirmado   España     04/03/2020
#
#                                                             Estados
#
# ['Estados']
# 337   BAJA CALIFORNIA    M   30   19/03/2020   confirmado   Unidos     09/03/2020
#
# 338      ZACATECAS       M   28   18/03/2020   confirmado   España     15/03/2020
#
# 339   CIUDAD DE MÉXICO   M   60   18/03/2020   confirmado   Contacto      NA
#
# 340   CIUDAD DE MÉXICO   M   38   13/03/2020   confirmado   Contacto      NA
#
# 341   CIUDAD DE MÉXICO   M   37   15/03/2020   confirmado   Contacto   16/03/2020
#
#                                                             Estados
#
# ['Estados']
# 342       PUEBLA         F   28   15/03/2020   confirmado    Unidos    17/03/2020
#
#                                                             Estados
#
# ['Estados']
# 343       TABASCO        M   30   13/03/2020   confirmado    Unidos    11/03/2020
#
# 344    QUINTANA ROO      M   60   17/03/2020   confirmado   España     15/03/2020
#
# 345    QUINTANA ROO      M   46   15/03/2020   confirmado   Contacto      NA
#
# 346   AGUASCALIENTES     M   18   19/03/2020   confirmado   España     16/03/2020
#
# 347    QUINTANA ROO      F   12   15/03/2020   confirmado   Contacto      NA
#
# 348    QUINTANA ROO      F   52   17/03/2020   confirmado   España     15/03/2020
#
# 349    QUINTANA ROO      M   16   13/03/2020   confirmado   Contacto      NA
#
# 350       JALISCO        F   24   14/03/2020   confirmado   Contacto      NA
#
# 351       JALISCO        M   19   16/03/2020   confirmado   España     16/03/2020
#
# 352     MICHOACÁN        F   48   15/03/2020   confirmado   Contacto   15/03/2020
#
# 353     MICHOACÁN        M   58   15/03/2020   confirmado   Contacto   15/03/2020
#
# 354    QUINTANA ROO      M   44   14/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
# 355    SAN LUIS POTOSÍ   M   37   19/03/2020   confirmado    Unidos    17/03/2020
#
#                                                             Estados
#
# ['Estados']
# 356    SAN LUIS POTOSÍ   F   32   18/03/2020   confirmado    Unidos    17/03/2020
#
#                                                             Estados
#
# ['Estados']
# 357    SAN LUIS POTOSÍ   M   38   18/03/2020   confirmado    Unidos    17/03/2020
#
# 358     MICHOACÁN        F   50   15/03/2020   confirmado   Contacto   15/03/2020
#
# 359     MICHOACÁN        M   56   15/03/2020   confirmado   Contacto   15/03/2020
#
# 360    SAN LUIS POTOSÍ   M   70   15/03/2020   confirmado   Contacto      NA
#
# 361     GUANAJUATO       F   20   15/03/2020   confirmado   España     16/03/2020
#
# 362     GUANAJUATO       F   32   16/03/2020   confirmado   España     16/03/2020
#
#                                                             Estados
#
# ['Estados']
# 363       PUEBLA         F   39   18/03/2020   confirmado   Unidos     13/03/2020
#
# 364     NUEVO LEÓN       F   63   13/03/2020   confirmado   Francia    14/03/2020
#
# 365   BAJA CALIFORNIA    M   51   21/03/2020   confirmado   Contacto      NA
#
# 366      GUERRERO        F   36   17/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
# 367    QUINTANA ROO      F   21   18/03/2020   confirmado    Unidos    18/03/2020
#
#                                                             Estados
#
# ['Estados']
# 368    QUINTANA ROO      F   19   11/03/2020   confirmado    Unidos    09/03/2020
#
# 369    QUINTANA ROO      M   48   19/03/2020   confirmado   Contacto   13/03/2020
#
# 370     TAMAULIPAS       M   29   20/03/2020   confirmado   Contacto      NA
#
# 371       OAXACA         F   34   20/03/2020   confirmado   Francia    17/03/2020
#
# ...
#
# 441     GUANAJUATO       M   29   16/03/2020   confirmado   España     16/03/2020
#
# 442     GUANAJUATO       F   41   18/03/2020   confirmado   España     16/03/2020
#
# 443       TABASCO        F   57   18/03/2020   confirmado   España     18/03/2020
#
# 444       HIDALGO        F   16   20/03/2020   confirmado   Contacto      NA
#
# 445       HIDALGO        M   17   13/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
# 446     GUANAJUATO       M   24   15/03/2020   confirmado    Unidos    19/03/2020
#
#                                                             Estados
#
# ['Estados']
# 447       JALISCO        M   36   15/03/2020   confirmado    Unidos    08/03/2020
#
#                                                             Estados
#
# ['Estados']
# 448       JALISCO        F   25   13/03/2020   confirmado    Unidos    06/03/2020
#
# 449   CIUDAD DE MÉXICO   F   60   14/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
# 450   CIUDAD DE MÉXICO   M   28   02/03/2020   confirmado    Unidos    15/03/2020
#
#                                                             Estados
#
# ['Estados']
# 451    QUINTANA ROO      M   42   21/03/2020   confirmado    Unidos    19/03/2020
#
# 452   CIUDAD DE MÉXICO   F   53   10/03/2020   confirmado   Francia    18/03/2020
#
# 453       JALISCO        F   50   12/03/2020   confirmado   España     09/03/2020
#
# 454       JALISCO        F   38   20/03/2020   confirmado   Contacto   23/03/2020
#
# 455   CIUDAD DE MÉXICO   M   47   17/03/2020   confirmado   España     14/03/2020
#
# 456   CIUDAD DE MÉXICO   M   20   16/03/2020   confirmado   Contacto   16/03/2020
#
# 457     MICHOACÁN        F   49   16/03/2020   confirmado   España     15/03/2020
#
#                                                             Estados
#
# ['Estados']
# 458   CIUDAD DE MÉXICO   F   29   16/03/2020   confirmado   Unidos     09/03/2020
#
# 459     TAMAULIPAS       M   75   22/03/2020   confirmado   Contacto      NA
#
#       BAJA CALIFORNIA
#
# ['BAJA CALIFORNIA']
# 460         SUR          M   40   21/03/2020   confirmado   Contacto      NA
#
#       BAJA CALIFORNIA
#
# ['BAJA CALIFORNIA']
# 461         SUR          F   31   21/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
# 462       JALISCO        M   49   12/03/2020   confirmado    Unidos    08/03/2020
#
#                                                             Estados
#
# ['Estados']
# 463       MÉXICO         M   45   16/03/2020   confirmado    Unidos    03/03/2020
#
# 464       CHIAPAS        M   45   13/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
# 465      TLAXCALA        F   19   16/03/2020   confirmado    Unidos    21/03/2020
#
# 466   CIUDAD DE MÉXICO   F   65   16/03/2020   confirmado   España     14/03/2020
#
# 467   CIUDAD DE MÉXICO   F   34   19/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
# 468      MORELOS         F   35   16/03/2020   confirmado    Unidos    16/03/2020
#
# 469   AGUASCALIENTES     M   53   23/03/2020   confirmado   España     23/03/2020
#
# 470   CIUDAD DE MÉXICO   M   45   13/03/2020   confirmado   España     19/03/2020
#
# 471   BAJA CALIFORNIA    F   50   18/03/2020   confirmado   Contacto      NA
#
# 472       JALISCO        F   33   21/03/2020   confirmado   Contacto      NA
#
# 473       JALISCO        F   20   22/03/2020   confirmado   Contacto      NA
#
#       BAJA CALIFORNIA                                       Estados
#
# ['BAJA CALIFORNIA,Estados']
# 474         SUR          M   46   21/03/2020   confirmado    Unidos    20/03/2020
#
# 475   AGUASCALIENTES     F   59   23/03/2020   confirmado   Contacto      NA
#
# 476       HIDALGO        F   24   13/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
# 477    QUINTANA ROO      M   20   13/03/2020   confirmado    Unidos    21/03/2020
#
# 478   CIUDAD DE MÉXICO   M   58   12/03/2020   confirmado   Contacto      NA
#
# 479       PUEBLA         F   31   16/03/2020   confirmado   España     15/03/2020
#
# 480       JALISCO        M   58   20/03/2020   confirmado   España     17/03/2020
#
# 481     MICHOACÁN        F   69   15/03/2020   confirmado   Contacto   23/03/2020
#
# 482   AGUASCALIENTES     M   60   20/03/2020   confirmado   Francia    12/03/2020
#
# 483    QUINTANA ROO      F   30   21/03/2020   confirmado   Francia    21/03/2020
#
# 484       SINALOA        F   47   16/03/2020   confirmado   España     15/03/2020
#
#                                                             Estados
#
# ['Estados']
# 485       JALISCO        F   20   20/03/2020   confirmado   Unidos     07/03/2020
#
# 486       JALISCO        M   72   18/03/2020   confirmado   Francia    17/03/2020
#
#                                                             Estados
#
# ['Estados']
# 487       YUCATÁN        M   30   18/03/2020   confirmado   Unidos     14/03/2020
#
# 488       OAXACA         F   16   23/03/2020   confirmado   Contacto   23/03/2020
#
#                                                             Estados
#
# ['Estados']
# 489       YUCATÁN        F   42   22/03/2020   confirmado    Unidos    14/03/2020
#
#                                                             Estados
#
# ['Estados']
# 490       JALISCO        M   54   12/03/2020   confirmado    Unidos    08/03/2020
#
# 491     QUERETARO        M   21   22/03/2020   confirmado   España     13/03/2020
#
# 492       MÉXICO         M   69   18/03/2020   confirmado   España     15/03/2020
#
#                                                             Estados
#
# ['Estados']
# 493       JALISCO        M   21   12/03/2020   confirmado   Unidos     07/03/2020
#
#                                                             Estados
#
# ['Estados']
# 494       HIDALGO        M   71   16/03/2020   confirmado   Unidos     13/03/2020
#
# 495       JALISCO        F   49   17/03/2020   confirmado   Contacto      NA
#
# 496    QUINTANA ROO      M   74   15/03/2020   confirmado   Contacto      NA
#
#                                                             Estados
#
# ['Estados']
# 497    QUINTANA ROO      M   51   12/03/2020   confirmado    Unidos    09/03/2020
#
#                                                             Estados
#
# ['Estados']
# 498       JALISCO        F   48   06/03/2020   confirmado    Unidos    05/02/2020
#
# 499       JALISCO        F   20   16/03/2020   confirmado   Contacto      NA
#
# 500     QUERETARO        F   46   20/03/2020   confirmado   Francia    06/03/2020
#
#                                                             Estados
#
# ['Estados']
# 501       JALISCO        M   72   12/03/2020   confirmado   Unidos     06/03/2020
#
# 502       MÉXICO         F   26   18/03/2020   confirmado   España     21/03/2020
#
# 503       PUEBLA         F   22   22/03/2020   confirmado   Contacto      NA
#
# 504     NUEVO LEÓN       F   30   18/03/2020   confirmado   España     16/03/2019
#
#                                                            Estados
#
# ['Estados']
# 505       PUEBLA        F   47   16/03/2020   confirmado   Unidos     15/03/2020
#
# 506       PUEBLA        M   42   18/03/2020   confirmado   Contacto      NA
#
# 507       JALISCO       M   50   14/03/2020   confirmado   Contacto      NA
#
# 508   SAN LUIS POTOSÍ   F   33   22/03/2020   confirmado   España     14/03/2020
#
#                                                            Estados
#
# ['Estados']
# 509       PUEBLA        M   48   16/03/2020   confirmado   Unidos     15/03/2020
#
#                                                            Estados
#
# ['Estados']
# 510      SINALOA        F   30   17/03/2020   confirmado   Unidos     15/03/2020
#
# 511      SINALOA        M   72   14/03/2020   confirmado   Contacto      NA
#
# 512      COAHUILA       M   42   19/03/2020   confirmado   Contacto      NA
#
# 513    NUEVO LEÓN       F   26   21/03/2020   confirmado   Contacto      NA
#
#                                                            Estados
#
# ['Estados']
# 514   BAJA CALIFORNIA   F   50   15/03/2020   confirmado    Unidos    13/03/2020
#
# 515      MORELOS        F   61   23/03/2020   confirmado   Contacto      NA
#
# 516      SONORA         M   44   17/03/2020   confirmado   España     10/03/2020
#
# 517      TABASCO        M   46   20/03/2020   confirmado   Contacto      NA
#
# 518    NUEVO LEÓN       M   26   18/03/2020   confirmado   España     16/03/2020
#
#                                                            Estados
#
# ['Estados']
# 519    NUEVO LEÓN       M   41   09/03/2020   confirmado   Unidos     09/03/2020
#
#                                                            Estados
#
# ['Estados']
# 520      SONORA         M   24   17/03/2020   confirmado   Unidos     19/03/2020
#
# 521      NAYARIT        M   53   21/03/2020   confirmado   Contacto   24/03/2020
#
# 522       PUEBLA        M   27   23/03/2020   confirmado   Contacto      NA
#
# 523       PUEBLA        F   35   21/03/2020   confirmado   Contacto      NA
#
# 524      NAYARIT        M   53   24/03/2020   confirmado   Contacto   24/03/2020
#
# 525     MICHOACÁN       F   62   15/03/2020   confirmado   Contacto   15/03/2020
#
# 526      SONORA         F   50   20/03/2020   confirmado   España     16/03/2020
#
# 527      YUCATÁN        M   53   19/03/2020   confirmado   Contacto   12/03/2020
#
# 528     QUERETARO       M   38   14/03/2020   confirmado   Contacto      NA
#
# 529   AGUASCALIENTES    F   74   22/03/2020   confirmado   Contacto      NA
#
# 530      YUCATÁN        M   23   17/03/2020   confirmado   Francia    21/03/2020
#
# 531      YUCATÁN        M   58   20/03/2020   confirmado   Contacto      NA
#
# 532      YUCATÁN        M   67   22/03/2020   confirmado   Contacto   21/03/2020
#
# 533      SINALOA        M   26   20/03/2020   confirmado   Contacto      NA
#
#                                                            Estados
#
# ['Estados']
# 534     QUERETARO       M   23   20/03/2020   confirmado    Unidos    17/03/2020
#
# 535   QUINTANA ROO      M   75   25/03/2020   confirmado   Contacto   20/03/2020
#
# 536      TABASCO        F   28   19/03/2020   confirmado   Contacto      NA
#
#                                                            Estados
#
# ['Estados']
# 537   QUINTANA ROO      F   49   20/03/2020   confirmado    Unidos    20/03/2020
#
# 538     QUERETARO       F   62   17/03/2020   confirmado   Contacto      NA
#
#                                                            Estados
#
# ['Estados']
# 539    NUEVO LEÓN       M   40   05/03/2020   confirmado    Unidos    10/03/2020
#
# 540    GUANAJUATO       M   51   20/03/2020   confirmado   España     15/03/2020
#
# 541    GUANAJUATO       F   28   20/03/2020   confirmado   Contacto   16/03/2020
#
# 542     ZACATECAS       F   57   12/03/2020   confirmado   Contacto   29/02/2020
#
# 543    GUANAJUATO       F   59   20/03/2020   confirmado   Contacto      NA
#
# 544    GUANAJUATO       M   26   15/03/2020   confirmado   España     14/03/2020
#
# 545   BAJA CALIFORNIA   M   25   20/03/2020   confirmado   Contacto   21/03/2020
#
# 546       JALISCO       F   19   17/03/2020   confirmado   Francia    11/03/2020
#
#                                                            Estados
#
# ['Estados']
# 547       JALISCO       F   19   16/03/2020   confirmado   Unidos     15/03/2020
#
#                                                            Estados
#
# ['Estados']
# 548   BAJA CALIFORNIA   F   41   20/03/2020   confirmado   Unidos     19/03/2020
#
#       BAJA CALIFORNIA                                      Estados
#
# ['BAJA CALIFORNIA,Estados']
# 549         SUR         M   44   20/03/2020   confirmado   Unidos     14/03/2020
#
# 550   BAJA CALIFORNIA   M   30   16/03/2020   confirmado   España     18/03/2020
#
# 551       PUEBLA        M   50   22/03/2020   confirmado   Contacto      NA
#
# 552   BAJA CALIFORNIA   F   64   13/03/2020   confirmado   Contacto      NA
#
#               BAJA CALIFORNIA                                                      Estados
#
# ['BAJA CALIFORNIA,Estados']
#   553               SUR                         M   66   22/03/2020   confirmado   Unidos     15/03/2020
#
#                                                                                    Estados
#
# ['Estados']
#   554               PUEBLA                      F   60   16/03/2020   confirmado   Unidos     11/03/2020
#
#   555              TABASCO                      F   26   16/03/2020   confirmado   Contacto      NA
#
#   556              TABASCO                      F   53   21/03/2020   confirmado   Contacto      NA
#
#   557              TABASCO                      M   31   21/03/2020   confirmado   Contacto      NA
#
#   558              TABASCO                      F   29   13/03/2020   confirmado   Contacto      NA
#
#   559              TABASCO                      M   67   19/03/2020   confirmado   Contacto      NA
#
#   560               PUEBLA                      M   44   18/03/2020   confirmado   Contacto      NA
#
#                                                                                    Estados
#
# ['Estados']
#    561              PUEBLA                      M   27   23/03/2020   confirmado    Unidos    18/03/2020
#
#   562              TABASCO                      M   31   17/03/2020   confirmado   Contacto      NA
#
#   563              TABASCO                      F   58   18/03/2020   confirmado   Contacto      NA
#
#   564               MÉXICO                      F   68   17/03/2020   confirmado   Contacto      NA
#
#   565               MÉXICO                      F   49   02/03/2020   confirmado   Contacto      NA
#
#   566               MÉXICO                      F   22   24/03/2020   confirmado   Contacto      NA
#
#   567               MÉXICO                      F   22   16/03/2020   confirmado   Contacto   15/03/2020
#
#   568               MÉXICO                      M   36   16/03/2020   confirmado   España     03/03/2020
#
#   569               MÉXICO                      F   33   12/03/2020   confirmado   Contacto      NA
#
#   570               MÉXICO                      M   37   21/03/2020   confirmado   Contacto      NA
#
#    571             HIDALGO                      F   49   23/03/2020   confirmado   Contacto   23/03/2020
#
#   572               MÉXICO                      F   36   16/03/2020   confirmado   Contacto      NA
#
#   573               MÉXICO                      F   31   21/03/2020   confirmado   Contacto      NA
#
#   574               MÉXICO                      F   48   16/03/2020   confirmado   Contacto      NA
#
#   575               MÉXICO                      M   60   20/03/2020   confirmado   Contacto      NA
#
#   576               MÉXICO                      F   33   22/03/2020   confirmado   Contacto      NA
#
#   577          SAN LUIS POTOSÍ                  M   56   13/03/2020   confirmado   Contacto      NA
#
#   578               MÉXICO                      F   33   10/03/2020   confirmado   Contacto      NA
#
#   579              TABASCO                      M   26   09/03/2020   confirmado   Contacto      NA
#
#   580               MÉXICO                      F   28   21/03/2020   confirmado   Contacto      NA
#
#    581              MÉXICO                      F   43   23/03/2020   confirmado   Contacto      NA
#
#   582               MÉXICO                      F   46   23/03/2020   confirmado   Contacto      NA
#
#   583               MÉXICO                      F   28   16/03/2020   confirmado   Contacto      NA
#
#   584               MÉXICO                      F   31   19/03/2020   confirmado   Contacto      NA
#
#   585               MÉXICO                      M   41   24/03/2020   confirmado   Contacto      NA
#
#
#
# ['']
# Fuente: SINAVE/DGE/InDRE
#
# ['', 'Fuente: SINAVE/DGE/InDRE']
# F: Femenino M: Masculino
#
# ['', 'Fuente: SINAVE/DGE/InDRE', 'F: Femenino M: Masculino']
# Corte: 26 de Marzo del 2020 a las 13:00 horas
#
# ['', 'Fuente: SINAVE/DGE/InDRE', 'F: Femenino M: Masculino', 'Corte: 26 de Marzo del 2020 a las 13:00 horas']
#
# ['', 'Fuente: SINAVE/DGE/InDRE', 'F: Femenino M: Masculino', 'Corte: 26 de Marzo del 2020 a las 13:00 horas', '']
